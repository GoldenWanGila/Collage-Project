# %%
import plotter
import pandas as pd

# %%
dataFrame = pd.read_csv('inputs/railway.csv')
dataFrame_localTrain = dataFrame[dataFrame['num']>=500]
dataFrame_localTrain = dataFrame_localTrain[dataFrame_localTrain['date'] >= '2021/01/22']
dataFrame_localTrain
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 107       Zhongli          0   5  2021/01/29  06:45  2133      Chiayi    1.0
# 190       Zhongli          0   1  2021/01/22  00:17  1287     Zhongli    0.0
# 191       Zhongli          0   2  2021/01/22  05:49  1109     Hsinchu    0.0
# 192       Zhongli          0   3  2021/01/22  06:05  2011    Changhua    2.0
# 193       Zhongli          0   4  2021/01/22  06:26  1107      Miaoli    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 107       D
# 190       D
# ...

# %%
dataFrame_localTrain_Fengyuan = dataFrame_localTrain[dataFrame_localTrain['Station']=='Fengyuan']
dataFrame_localTrain_Taiyuan = dataFrame_localTrain[dataFrame_localTrain['Station']=="Taiyuan"]
dataFrame_localTrain_Taichung = dataFrame_localTrain[dataFrame_localTrain['Station']=='Taichung']
dataFrame_localTrain_Xinwuri = dataFrame_localTrain[dataFrame_localTrain['Station']=='Xinwuri']
dataFrame_localTrain_Chenggong = dataFrame_localTrain[dataFrame_localTrain['Station']=='Tanzi']
dataFrame_localTrain_Changhua = dataFrame_localTrain[dataFrame_localTrain['Station']=='Changhua']
dataFrame_localTrain_Yuanlin = dataFrame_localTrain[dataFrame_localTrain['Station']=='Yuanlin']

# %%
dataFrameList = [dataFrame_localTrain_Fengyuan, dataFrame_localTrain_Taiyuan, dataFrame_localTrain_Taichung, dataFrame_localTrain_Xinwuri, dataFrame_localTrain_Chenggong, dataFrame_localTrain_Changhua, dataFrame_localTrain_Yuanlin]
mseList = []
for position in range(len(dataFrameList)):
    mseList.append([])
    dataFrameStart = dataFrameList[position]
    for dataFrameEnd in dataFrameList:
        if set(dataFrameStart['Station']) != set(dataFrameEnd['Station']):
            x,y = plotter.arrangeDataFrame(dataFrameStart, dataFrameEnd, 1)
            mseList[position].append(plotter.getRMSE(x,y))
        else:
            mseList[position].append('--')
# Out:
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
stationList = ['Fengyuan', 'Taiyuan', 'Taichung', 'Xinwuri', 'Chenggong', 'Changhua', 'Yuanlin']

mseDict = dict(zip(stationList, mseList))
mse_df = pd.DataFrame(mseDict, index=stationList)

# %%
mse_df
# Out:
#                    Fengyuan           Taiyuan          Taichung  \
# Fengyuan                 --  1.04582344729789  1.30325968086705
# Taiyuan    1.05823265713921                --  1.00033585289858
# Taichung   1.41132147138246  1.07863048247742                --
# Xinwuri    1.65531589524830  1.42912254029255  1.08722173164757
# Chenggong  1.90091317526573  1.72491456378408  1.58618299284431
# Changhua   1.72247562415651  1.50659393663957  1.44523226411444
# Yuanlin    2.11977831773208  1.93473384477671  1.93344620602178
#
#                     Xinwuri          Chenggong           Changhua  \
# Fengyuan   1.55993680009539   1.58847268868614   1.70230341758622
# Taiyuan    1.36903363436148   1.41771181835136   1.50541436228009
# Taichung   1.15233014732884   1.44389321260483   1.56933038881274
# Xinwuri                  --   1.27045074831600   1.31264612658131
# Chenggong  1.31910388994215                 --  0.794651834990983
# ...

# %%
import datetime

# %%
dataFrame_localTrain_weekday = dataFrame_localTrain[dataFrame_localTrain['date'].apply(lambda date: datetime.date(int(date[:4]), int(date[5:7]), int(date[8:])).isoweekday() < 6)]
dataFrame_localTrain_weekday
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 107       Zhongli          0   5  2021/01/29  06:45  2133      Chiayi    1.0
# 190       Zhongli          0   1  2021/01/22  00:17  1287     Zhongli    0.0
# 191       Zhongli          0   2  2021/01/22  05:49  1109     Hsinchu    0.0
# 192       Zhongli          0   3  2021/01/22  06:05  2011    Changhua    2.0
# 193       Zhongli          0   4  2021/01/22  06:26  1107      Miaoli    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 107       D
# 190       D
# ...

# %%
dataFrame_localTrain_weekend = dataFrame_localTrain[dataFrame_localTrain['date'].apply(lambda date: datetime.date(int(date[:4]), int(date[5:7]), int(date[8:])).isoweekday() > 5)]
dataFrame_localTrain_weekend
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 286       Zhongli          0   1  2021/01/23  00:17  1287     Zhongli    0.0
# 287       Zhongli          0   2  2021/01/23  05:49  1109     Hsinchu    1.0
# 288       Zhongli          0   3  2021/01/23  06:05  2011    Changhua    4.0
# 289       Zhongli          0   4  2021/01/23  06:26  1107      Miaoli    0.0
# 290       Zhongli          0   5  2021/01/23  06:45  2133      Chiayi    1.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 320821  Kaohsiung          1  93  2021/04/04  22:13  3288    Yongkang    0.0
# 320822  Kaohsiung          1  94  2021/04/04  22:20  3088  Xinzuoying    0.0
# 320823  Kaohsiung          1  95  2021/04/04  22:34  3292      Tainan    0.0
# 320824  Kaohsiung          1  96  2021/04/04  22:55  3294      Tainan    0.0
# 320826  Kaohsiung          1  98  2021/04/04  23:43  3348  Xinzuoying    5.0
#
#        type
# 286       D
# 287       D
# ...

# %% [markdown]
# ## 假日

# %%
dataFrame_localTrain_weekend_Fengyuan = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Fengyuan']
dataFrame_localTrain_weekend_Taiyuan = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Taiyuan']
dataFrame_localTrain_weekend_Taichung = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Taichung']
dataFrame_localTrain_weekend_Xinwuri = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Xinwuri']
dataFrame_localTrain_weekend_Chenggong = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Tanzi']
dataFrame_localTrain_weekend_Changhua = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Changhua']
dataFrame_localTrain_weekend_Yuanlin = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Yuanlin']

# %%
dataFrameList = [dataFrame_localTrain_weekend_Fengyuan, dataFrame_localTrain_weekend_Taiyuan, dataFrame_localTrain_weekend_Taichung, dataFrame_localTrain_weekend_Xinwuri, dataFrame_localTrain_weekend_Chenggong, dataFrame_localTrain_weekend_Changhua, dataFrame_localTrain_weekend_Yuanlin]
mseList = []
for position in range(len(dataFrameList)):
    mseList.append([])
    dataFrameStart = dataFrameList[position]
    for dataFrameEnd in dataFrameList:
        if set(dataFrameStart['Station']) != set(dataFrameEnd['Station']):
            x,y = plotter.arrangeDataFrame(dataFrameStart, dataFrameEnd, 1)
            mseList[position].append(plotter.getRMSE(x,y))
        else:
            mseList[position].append('--')

stationList = ['Fengyuan', 'Taiyuan', 'Taichung', 'Xinwuri', 'Chenggong', 'Changhua', 'Yuanlin']
mseDict = dict(zip(stationList, mseList))
mse_df = pd.DataFrame(mseDict, index=stationList)
# Out:
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
mse_df
# Out:
#                    Fengyuan           Taiyuan          Taichung  \
# Fengyuan                 --  1.09288187559240  1.35913102947009
# Taiyuan    1.10489743164106                --  1.06184695601346
# Taichung   1.48136698665275  1.14192736294236                --
# Xinwuri    1.72739141167885  1.48127240933171  1.09509832995567
# Chenggong  1.92043535448658  1.79600273108857  1.69356503371986
# Changhua   1.56103803859490  1.46788733534340  1.45527530447564
# Yuanlin    2.05166273328732  1.93614310575807  1.92533612541340
#
#                     Xinwuri          Chenggong           Changhua  \
# Fengyuan   1.52244697372518   1.70153445456968   1.68659140662251
# Taiyuan    1.27498557174121   1.55219204622015   1.52864958036807
# Taichung   1.11352563087471   1.57716287400507   1.64732950284069
# Xinwuri                  --   1.33122799143914   1.37819853399774
# Chenggong  1.31871319838301                 --  0.771359527437672
# ...

# %% [markdown]
# ## 平日尖峰

# %%
# 上班
dataFrame_localTrain_weekday_onWork = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['time'] >= '06:00']
dataFrame_localTrain_weekday_onWork = dataFrame_localTrain_weekday_onWork[dataFrame_localTrain_weekday_onWork['time'] <= '08:00']
# 下班
dataFrame_localTrain_weekday_offWork = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['time'] >= '17:00']
dataFrame_localTrain_weekday_offWork = dataFrame_localTrain_weekday_offWork[dataFrame_localTrain_weekday_offWork['time'] <= '20:00']

# %%
dataFrame_localTrain_weekday_onPeak = pd.concat([dataFrame_localTrain_weekday_onWork, dataFrame_localTrain_weekday_offWork])
dataFrame_localTrain_weekday_onPeak
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 107       Zhongli          0   5  2021/01/29  06:45  2133      Chiayi    1.0
# 192       Zhongli          0   3  2021/01/22  06:05  2011    Changhua    2.0
# 193       Zhongli          0   4  2021/01/22  06:26  1107      Miaoli    0.0
# 194       Zhongli          0   5  2021/01/22  06:45  2133      Chiayi    0.0
# 196       Zhongli          0   7  2021/01/22  07:14  1117      Miaoli    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 320997  Kaohsiung          1  75  2021/04/06  18:54  3258      Ershui    0.0
# 320999  Kaohsiung          1  77  2021/04/06  19:12   708  Xinzuoying    0.0
# 321000  Kaohsiung          1  78  2021/04/06  19:17  3082  Xinzuoying    0.0
# 321002  Kaohsiung          1  80  2021/04/06  19:36  3262       Houli    0.0
# 321003  Kaohsiung          1  81  2021/04/06  19:48  3266     Shanhua    0.0
#
#        type
# 107       D
# 192       D
# ...

# %%
dataFrame_localTrain_weekday_onPeak_Fengyuan = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Fengyuan']
dataFrame_localTrain_weekday_onPeak_Taiyuan = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Taiyuan']
dataFrame_localTrain_weekday_onPeak_Taichung = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Taichung']
dataFrame_localTrain_weekday_onPeak_Xinwuri = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Xinwuri']
dataFrame_localTrain_weekday_onPeak_Chenggong = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Tanzi']
dataFrame_localTrain_weekday_onPeak_Changhua = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Changhua']
dataFrame_localTrain_weekday_onPeak_Yuanlin = dataFrame_localTrain_weekday_onPeak[dataFrame_localTrain_weekday_onPeak['Station']=='Yuanlin']

# %%
dataFrameList = [dataFrame_localTrain_weekday_onPeak_Fengyuan, dataFrame_localTrain_weekday_onPeak_Taiyuan, dataFrame_localTrain_weekday_onPeak_Taichung, dataFrame_localTrain_weekday_onPeak_Xinwuri, dataFrame_localTrain_weekday_onPeak_Chenggong, dataFrame_localTrain_weekday_onPeak_Changhua, dataFrame_localTrain_weekday_onPeak_Yuanlin]

mseList = []
for position in range(len(dataFrameList)):
    mseList.append([])
    dataFrameStart = dataFrameList[position]
    for dataFrameEnd in dataFrameList:
        if set(dataFrameStart['Station']) != set(dataFrameEnd['Station']):
            x,y = plotter.arrangeDataFrame(dataFrameStart, dataFrameEnd, 1)
            mseList[position].append(plotter.getRMSE(x,y))
        else:
            mseList[position].append('--')

stationList = ['Fengyuan', 'Taiyuan', 'Taichung', 'Xinwuri', 'Chenggong', 'Changhua', 'Yuanlin']
mseDict = dict(zip(stationList, mseList))
mse_df = pd.DataFrame(mseDict, index=stationList)
# Out:
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
mse_df
# Out:
#                     Fengyuan            Taiyuan           Taichung  \
# Fengyuan                  --  0.890366547492208   1.08614064881073
# Taiyuan    0.818139184849793                 --  0.649963100977926
# Taichung    1.23928125840354  0.909833334161656                 --
# Xinwuri     1.37458253309036   1.09158225508040   1.08441819990144
# Chenggong   1.62302722093076   1.50514818613520   1.50746630341695
# Changhua    1.38324577128053   1.30717945640085   1.30614099165057
# Yuanlin     1.47527173140231   1.40727957502544   1.30178005592733
#
#                      Xinwuri          Chenggong           Changhua  \
# Fengyuan    1.23583307402150   1.45468183233042   1.60443917889215
# Taiyuan    0.890374341724732   1.24900529515299   1.31148695904661
# Taichung    1.05007634103657   1.53801471972935   1.69766887702905
# Xinwuri                   --   1.33070399847353   1.39268833949741
# Chenggong   1.34544316122217                 --  0.846844794250190
# ...

# %% [markdown]
# ## 平日離峰

# %%
dataFrame_localTrain_weekday_offPeak = dataFrame_localTrain_weekday.drop(index=dataFrame_localTrain_weekday_onPeak.index)
dataFrame_localTrain_weekday_offPeak
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 190       Zhongli          0   1  2021/01/22  00:17  1287     Zhongli    0.0
# 191       Zhongli          0   2  2021/01/22  05:49  1109     Hsinchu    0.0
# 201       Zhongli          0  12  2021/01/22  08:03   507  Xinzuoying    2.0
# 203       Zhongli          0  13  2021/01/22  08:14  1127      Miaoli    1.0
# 204       Zhongli          0  14  2021/01/22  08:24  1131     Hsinchu    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 190       D
# 191       D
# ...

# %%
dataFrame_localTrain_weekday_offPeak_Fengyuan = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Fengyuan']
dataFrame_localTrain_weekday_offPeak_Taiyuan = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Taiyuan']
dataFrame_localTrain_weekday_offPeak_Taichung = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Taichung']
dataFrame_localTrain_weekday_offPeak_Xinwuri = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Xinwuri']
dataFrame_localTrain_weekday_offPeak_Chenggong = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Tanzi']
dataFrame_localTrain_weekday_offPeak_Changhua = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Changhua']
dataFrame_localTrain_weekday_offPeak_Yuanlin = dataFrame_localTrain_weekday_offPeak[dataFrame_localTrain_weekday_offPeak['Station']=='Yuanlin']

# %%
dataFrameList = [dataFrame_localTrain_weekday_offPeak_Fengyuan, dataFrame_localTrain_weekday_offPeak_Taiyuan, dataFrame_localTrain_weekday_offPeak_Taichung, dataFrame_localTrain_weekday_offPeak_Xinwuri, dataFrame_localTrain_weekday_offPeak_Chenggong, dataFrame_localTrain_weekday_offPeak_Changhua, dataFrame_localTrain_weekday_offPeak_Yuanlin]

mseList = []
for position in range(len(dataFrameList)):
    mseList.append([])
    dataFrameStart = dataFrameList[position]
    for dataFrameEnd in dataFrameList:
        if set(dataFrameStart['Station']) != set(dataFrameEnd['Station']):
            x,y = plotter.arrangeDataFrame(dataFrameStart, dataFrameEnd, 1)
            mseList[position].append(plotter.getRMSE(x,y))
        else:
            mseList[position].append('--')

stationList = ['Fengyuan', 'Taiyuan', 'Taichung', 'Xinwuri', 'Chenggong', 'Changhua', 'Yuanlin']
mseDict = dict(zip(stationList, mseList))
mse_df = pd.DataFrame(mseDict, index=stationList)
# Out:
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
mse_df
# Out:
#                    Fengyuan           Taiyuan          Taichung  \
# Fengyuan                 --  1.01152431551592  1.23815430923720
# Taiyuan    1.04448866493379                --  1.01005791756533
# Taichung   1.33988309868791  1.02952974294090                --
# Xinwuri    1.64417039425499  1.46149021237496  1.00893410915533
# Chenggong  1.82883769933350  1.63951835142997  1.44407820183106
# Changhua   1.63656165303165  1.49049219406089  1.36771943875387
# Yuanlin    2.15692261157795  2.02436764844307  1.93155754831458
#
#                     Xinwuri          Chenggong           Changhua  \
# Fengyuan   1.65273630206809   1.47233173741188   1.70066879462530
# Taiyuan    1.55284737719413   1.34106540346644   1.54898367158534
# Taichung   1.19111948074017   1.25567393222426   1.46686790636315
# Xinwuri                  --   1.07470002509883   1.17067847685515
# Chenggong  1.20406642042126                 --  0.766145678631600
# ...

# %% [markdown]
# ## 事故
