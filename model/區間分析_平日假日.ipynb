# %%
import numpy as np
import pandas as pd
import plotter
import datetime
pd.set_option('display.max_rows', 110)

# %%
dataFrame = pd.read_csv('inputs/railway.csv')
dataFrame_localTrain = dataFrame[dataFrame['type']=='D']
dataFrame_localTrain
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 0         Zhongli          0   1  2021/01/20  00:17  1287     Zhongli    1.0
# 1         Zhongli          0   2  2021/01/20  05:49  1109     Hsinchu    1.0
# 2         Zhongli          0   3  2021/01/20  06:05  2011    Changhua    0.0
# 3         Zhongli          0   4  2021/01/20  06:26  1107      Miaoli    0.0
# 4         Zhongli          0   5  2021/01/20  06:45  2133      Chiayi    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 0         D
# 1         D
# ...

# %%
dataFrame_localTrain_weekday = dataFrame_localTrain[dataFrame_localTrain['date'].apply(lambda date: datetime.date(int(date[:4]), int(date[5:7]), int(date[8:])).isoweekday() < 6)]
dataFrame_localTrain_weekday
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 0         Zhongli          0   1  2021/01/20  00:17  1287     Zhongli    1.0
# 1         Zhongli          0   2  2021/01/20  05:49  1109     Hsinchu    1.0
# 2         Zhongli          0   3  2021/01/20  06:05  2011    Changhua    0.0
# 3         Zhongli          0   4  2021/01/20  06:26  1107      Miaoli    0.0
# 4         Zhongli          0   5  2021/01/20  06:45  2133      Chiayi    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 0         D
# 1         D
# ...

# %%
dataFrame_localTrain_weekend = dataFrame_localTrain[dataFrame_localTrain['date'].apply(lambda date: datetime.date(int(date[:4]), int(date[5:7]), int(date[8:])).isoweekday() > 5)]
dataFrame_localTrain_weekend
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 286       Zhongli          0   1  2021/01/23  00:17  1287     Zhongli    0.0
# 287       Zhongli          0   2  2021/01/23  05:49  1109     Hsinchu    1.0
# 288       Zhongli          0   3  2021/01/23  06:05  2011    Changhua    4.0
# 289       Zhongli          0   4  2021/01/23  06:26  1107      Miaoli    0.0
# 290       Zhongli          0   5  2021/01/23  06:45  2133      Chiayi    1.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 320821  Kaohsiung          1  93  2021/04/04  22:13  3288    Yongkang    0.0
# 320822  Kaohsiung          1  94  2021/04/04  22:20  3088  Xinzuoying    0.0
# 320823  Kaohsiung          1  95  2021/04/04  22:34  3292      Tainan    0.0
# 320824  Kaohsiung          1  96  2021/04/04  22:55  3294      Tainan    0.0
# 320826  Kaohsiung          1  98  2021/04/04  23:43  3348  Xinzuoying    5.0
#
#        type
# 286       D
# 287       D
# ...

# %% [markdown]
# ## 平日

# %% [markdown]
# ### 1. 豐原到員林的各站dataFrame

# %%
dataFrame_localTrain_weekday_Fengyuan = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Fengyuan']
dataFrame_localTrain_weekday_Taichung = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Taichung']
dataFrame_localTrain_weekday_Xinwuri = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Xinwuri']
dataFrame_localTrain_weekday_Chenggong = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Tanzi']
dataFrame_localTrain_weekday_Changhua = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Changhua']
dataFrame_localTrain_weekday_Yuanlin = dataFrame_localTrain_weekday[dataFrame_localTrain_weekday['Station']=='Yuanlin']

# %% [markdown]
# ### 2. 豐原到台中(逆行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Fengyuan, dataFrame_localTrain_weekday_Taichung, 1)
# plotter.plot(x,y)

# %% [markdown]
# ### 3. 台中到新烏日(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Taichung, dataFrame_localTrain_weekday_Xinwuri, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9817688249581691
# Modela intercept: 0.3456869032936063
# LinearRegression Score:  0.8833848218037958
# {x: 18.9613068000519, y: 18.9613068000519}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9166064891457675
# 1.07063490428394

# %% [markdown]
# ### 4. 新烏日到成功(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Xinwuri, dataFrame_localTrain_weekday_Chenggong, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9400510085283967
# Modela intercept: 0.2775097894042775
# LinearRegression Score:  0.8709780966287125
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 4.62909854848401, y: 4.62909854848401}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8867479290668239
# 1.28294248604095

# %% [markdown]
# ### 5. 成功到彰化(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Chenggong, dataFrame_localTrain_weekday_Changhua, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.914986807826845
# Modela intercept: -0.22129704181502063
# LinearRegression Score:  0.9516018229719804
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: -2.60309060462384, y: -2.60309060462384}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.966707048809202
# 0.671812410719509

# %% [markdown]
# ### 6. 彰化到員林(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Changhua, dataFrame_localTrain_weekday_Yuanlin, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.4814747309025488
# Modela intercept: 0.6938700906212368
# LinearRegression Score:  0.4008788318110936
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 1.33816061043465, y: 1.33816061043465}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.7840283095992924
# 1.34860746881752

# %% [markdown]
# ### 7. 員林到彰化(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Yuanlin, dataFrame_localTrain_weekday_Changhua, 0)
# plotter.plot(y,x)

# %% [markdown]
# ### 8. 彰化到成功(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Changhua, dataFrame_localTrain_weekday_Chenggong, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9802698805527182
# Modela intercept: 0.1921306788943078
# LinearRegression Score:  0.9302793360600269
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 9.73793794850926, y: 9.73793794850926}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9383607951363045
# 1.23679347351906

# %% [markdown]
# ### 9. 成功到新烏日(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Chenggong, dataFrame_localTrain_weekday_Xinwuri, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     1.0035792987232794
# Modela intercept: 0.23050259608954926
# LinearRegression Score:  0.9235484899090503
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: -64.3988149383410, y: -64.3988149383410}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9248394438816855
# 1.27394323071694

# %% [markdown]
# ### 10. 新烏日到台中(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Xinwuri, dataFrame_localTrain_weekday_Taichung, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     1.019744455316972
# Modela intercept: 0.3667835522019498
# LinearRegression Score:  0.8803848196576675
# {x: -18.5765343390712, y: -18.5765343390712}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.896239274450252
# 1.45633111246971

# %% [markdown]
# ### 11. 台中到豐原(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekday_Taichung, dataFrame_localTrain_weekday_Fengyuan, 0)
# plotter.plot(y,x)

# %% [markdown]
# ## 假日

# %% [markdown]
# ### 1. 豐原到員林的各站dataFrame

# %%
dataFrame_localTrain_weekend_Fengyuan = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Fengyuan']
dataFrame_localTrain_weekend_Taichung = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Taichung']
dataFrame_localTrain_weekend_Xinwuri = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Xinwuri']
dataFrame_localTrain_weekend_Chenggong = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Tanzi']
dataFrame_localTrain_weekend_Changhua = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Changhua']
dataFrame_localTrain_weekend_Yuanlin = dataFrame_localTrain_weekend[dataFrame_localTrain_weekend['Station']=='Yuanlin']

# %% [markdown]
# ### 2. 豐原到台中(逆行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Fengyuan, dataFrame_localTrain_weekend_Taichung, 1)
# plotter.plot(x,y)

# %% [markdown]
# ### 3. 台中到新烏日(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Taichung, dataFrame_localTrain_weekend_Xinwuri, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9509013877608055
# Modela intercept: 0.3671703975846883
# LinearRegression Score:  0.8886518909663587
# {x: 7.47822353503464, y: 7.47822353503464}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9069490385732538
# 1.13932720166772

# %% [markdown]
# ### 4. 新烏日到成功(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Xinwuri, dataFrame_localTrain_weekend_Chenggong, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9673401723785201
# Modela intercept: 0.21270098301091034
# LinearRegression Score:  0.8741637795640271
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 6.51261805408363, y: 6.51261805408363}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8970185229812069
# 1.27981410074977

# %% [markdown]
# ### 5. 成功到彰化(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Chenggong, dataFrame_localTrain_weekend_Changhua, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9585463565045366
# Modela intercept: -0.3030788259949344
# LinearRegression Score:  0.9626019129560139
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: -7.31127110764354, y: -7.31127110764354}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9749744281127221
# 0.633212115915272

# %% [markdown]
# ### 6. 彰化到員林(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Changhua, dataFrame_localTrain_weekend_Yuanlin, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.883983320459777
# Modela intercept: 0.34181107992566506
# LinearRegression Score:  0.7842060977255174
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 2.94622360578040, y: 2.94622360578040}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8688404133717517
# 1.50183327666474

# %% [markdown]
# ### 7. 員林到彰化(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Yuanlin, dataFrame_localTrain_weekend_Changhua, 0)
# plotter.plot(y,x)

# %% [markdown]
# ### 8. 彰化到成功(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Changhua, dataFrame_localTrain_weekend_Chenggong, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9851559380117575
# Modela intercept: 0.20149684703230974
# LinearRegression Score:  0.9784820537944614
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 13.5742391261841, y: 13.5742391261841}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9809592612932247
# 1.32948465554753

# %% [markdown]
# ### 9. 成功到新烏日(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Chenggong, dataFrame_localTrain_weekend_Xinwuri, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9898276662419001
# Modela intercept: 0.19510291081017517
# LinearRegression Score:  0.9832439218666779
# C:\Users\sunlo\Desktop\大學\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 19.1797590847645, y: 19.1797590847645}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9836626906776302
# 1.15081094681365

# %% [markdown]
# ### 10. 新烏日到台中(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Xinwuri, dataFrame_localTrain_weekend_Taichung, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     1.0004450258091269
# Modela intercept: 0.4334983984286376
# LinearRegression Score:  0.9709090455976651
# {x: -974.097208600334, y: -974.097208600334}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9736933006798976
# 1.38883823647993

# %% [markdown]
# ### 11. 台中到豐原(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_weekend_Taichung, dataFrame_localTrain_weekend_Fengyuan, 0)
# plotter.plot(y,x)
