# %%
import numpy as np
import pandas as pd
import plotter
pd.set_option('display.max_rows', 110)

# %%
dataFrame = pd.read_csv('inputs/railway.csv')
dataFrame_localTrain = dataFrame[dataFrame['type']=='D']
dataFrame_localTrain
# Out:
#           Station  direction  id        date   time   num        dest  delay  \
# 0         Zhongli          0   1  2021/01/20  00:17  1287     Zhongli    1.0
# 1         Zhongli          0   2  2021/01/20  05:49  1109     Hsinchu    1.0
# 2         Zhongli          0   3  2021/01/20  06:05  2011    Changhua    0.0
# 3         Zhongli          0   4  2021/01/20  06:26  1107      Miaoli    0.0
# 4         Zhongli          0   5  2021/01/20  06:45  2133      Chiayi    0.0
# ...           ...        ...  ..         ...    ...   ...         ...    ...
# 321013  Kaohsiung          1  91  2021/04/06  22:13  3288    Yongkang    0.0
# 321014  Kaohsiung          1  92  2021/04/06  22:20  3088  Xinzuoying    1.0
# 321015  Kaohsiung          1  93  2021/04/06  22:34  3292      Tainan    0.0
# 321016  Kaohsiung          1  94  2021/04/06  22:55  3294      Tainan    0.0
# 321018  Kaohsiung          1  96  2021/04/06  23:43  3348  Xinzuoying    0.0
#
#        type
# 0         D
# 1         D
# ...

# %% [markdown]
# # 先找出苗栗到員林路段上，所有共通的車次

# %%
dataFrame_localTrain_Miaoli = dataFrame_localTrain[dataFrame_localTrain['Station']=='Miaoli']
dataFrame_localTrain_Fengyuan = dataFrame_localTrain[dataFrame_localTrain['Station']=='Fengyuan']
dataFrame_localTrain_Taichung = dataFrame_localTrain[dataFrame_localTrain['Station']=='Taichung']
dataFrame_localTrain_Xinwuri = dataFrame_localTrain[dataFrame_localTrain['Station']=='Xinwuri']
dataFrame_localTrain_Chenggong = dataFrame_localTrain[dataFrame_localTrain['Station']=='Tanzi']
dataFrame_localTrain_Changhua = dataFrame_localTrain[dataFrame_localTrain['Station']=='Changhua']
dataFrame_localTrain_Yuanlin = dataFrame_localTrain[dataFrame_localTrain['Station']=='Yuanlin']

# %% [markdown]
# ## 苗栗到豐原(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Miaoli, dataFrame_localTrain_Fengyuan, 1)
plotter.plot(x,y)
# Out:
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# Modela slope:     0.6807621323234143
# Modela intercept: -0.11974466834503916
# LinearRegression Score:  0.7069636987838626
# {x: -0.375095439699999, y: -0.375095439699999}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8076245204051445
# 1.42791981741608

# %% [markdown]
# ## 豐原到臺中(逆行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Fengyuan, dataFrame_localTrain_Taichung, 1)
# plotter.plot(x,y)

# %% [markdown]
# ## 臺中到新烏日(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Taichung, dataFrame_localTrain_Xinwuri, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9723592184393588
# Modela intercept: 0.3511156647319653
# LinearRegression Score:  0.8847777771156654
# {x: 12.7028124715524, y: 12.7028124715524}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.911459766877787
# 1.10583201601746

# %% [markdown]
# ## 新烏日到彰化(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Xinwuri, dataFrame_localTrain_Changhua, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.89256702592802
# Modela intercept: -0.04313013571330826
# LinearRegression Score:  0.8604019715109654
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: -0.401460874427726, y: -0.401460874427726}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8963876937788028
# 1.17834554296531

# %% [markdown]
# ## 新烏日到成功(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Xinwuri, dataFrame_localTrain_Chenggong, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9479428947973527
# Modela intercept: 0.26012372324786526
# LinearRegression Score:  0.8718495981213915
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 4.99689182168812, y: 4.99689182168812}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8856468270831296
# 1.30665548864757

# %% [markdown]
# ## 成功到彰化(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Chenggong, dataFrame_localTrain_Changhua, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.9281008401443369
# Modela intercept: -0.24372524700643972
# LinearRegression Score:  0.9546917947429137
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: -3.38982051383794, y: -3.38982051383794}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9688312982343662
# 0.666779092438308

# %% [markdown]
# ## 彰化到員林(逆行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Changhua, dataFrame_localTrain_Yuanlin, 1)
plotter.plot(x,y)
# Out:
# Modela slope:     0.6109183910152526
# Modela intercept: 0.5967054560585776
# LinearRegression Score:  0.5234158743192012
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 1.53362544586879, y: 1.53362544586879}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.8172794268100187
# 1.41385393085495

# %% [markdown]
# ## 員林到彰化(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Yuanlin, dataFrame_localTrain_Changhua, 0)
# plotter.plot(y,x)

# %% [markdown]
# ## 彰化到新烏日(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Changhua, dataFrame_localTrain_Xinwuri, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.985689286465033
# Modela intercept: 0.20103674300035035
# LinearRegression Score:  0.9419384613321582
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 14.0479887679349, y: 14.0479887679349}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9460874537034807
# 1.50041374564720

# %% [markdown]
# ## 彰化到成功(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Changhua, dataFrame_localTrain_Chenggong, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9833044433905987
# Modela intercept: 0.19191302484915695
# LinearRegression Score:  0.9591796760833744
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 11.4948563464541, y: 11.4948563464541}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9630099107871152
# 1.27946080885105

# %% [markdown]
# ## 成功到新烏日(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Chenggong, dataFrame_localTrain_Xinwuri, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9948106957689588
# Modela intercept: 0.22833110302159465
# LinearRegression Score:  0.959300821164185
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 44.0003308450834, y: 44.0003308450834}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.95981421708233
# 1.24512787699792

# %% [markdown]
# ## 新烏日到臺中(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Xinwuri, dataFrame_localTrain_Taichung, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     1.0078604902505752
# Modela intercept: 0.39401369716155576
# LinearRegression Score:  0.9337472411224562
# {x: -50.1258426129952, y: -50.1258426129952}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9391418321453564
# 1.47204459214126

# %% [markdown]
# ## 臺中到豐原(順行)

# %%
# x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Taichung, dataFrame_localTrain_Fengyuan, 0)
# plotter.plot(y,x)

# %% [markdown]
# ## 豐原到苗栗(順行)

# %%
x,y = plotter.arrangeDataFrame(dataFrame_localTrain_Fengyuan, dataFrame_localTrain_Miaoli, 0)
plotter.plot(y,x)
# Out:
# Modela slope:     0.9739371247964115
# Modela intercept: 0.191023318963492
# LinearRegression Score:  0.9130572601685881
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# C:\Users\sunlo\Desktop\大學\專題\專題\台鐵誤點\model\plotter.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_target_dataFrame.sort_values(by=['date','num'], inplace=True)
# {x: 7.32932638748879, y: 7.32932638748879}
# 算出允許誤差
# xgboost、lasso比較
# xg Score:  0.9252903770837239
# 2.47629627175009
